# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
train_df = pd.read_csv("../train_df.csv", index_col=0)

# %%
import numpy as np

general_feature_name_to_dtype = {
    "date": object,
    "orgid": np.int64,
    "userid": np.int64,
    "has_reaction": bool,
    "has_review": bool,
    "rating": np.int64,
    "reaction": object,
    "time": np.int64,
}



general_feature_names = list(general_feature_name_to_dtype.keys())

user_feature_name_to_dtype = {
    "date": object,
    "orgid": np.int64,
    "userid": np.int64,

    'user_1': np.int64,
    'user_4': np.int64,
    'user_5': object,
    'user_6': object,
    'user_8': object,
    'user_9': np.int64,

    'user_10': np.int64,
    'user_12': np.int64,
    'user_13': object,
    'user_15': np.int64,
    'user_16': bool,
    'user_17': np.int64,
    'user_18': np.int64,
    'user_19': np.int64,

    'user_21': object,
    'user_22': object,
    'user_23': object,
    'user_24': object,
    'user_25': object,
    'user_26': object,
    'user_27': object,
    'user_28': object,
    'user_29': object,

    'user_30': object,
    'user_31': object,
    'user_32': object,
    'user_33': object,
    'user_34': object,
    'user_35': object,
    'user_36': object,
    'user_37': object,
    'user_38': object,
    'user_39': object,

    'user_40': object,
    'user_41': object,
    'user_42': object,
    'user_43': object,
    'user_44': object,
    'user_45': object,
    'user_46': object,
    'user_47': object,
    'user_48': object,
    'user_49': object,

    'user_50': object,
    'user_51': object,
    'user_52': object,
    'user_53': object,
    'user_54': object,
    'user_55': object,
    'user_56': object,
    'user_57': np.float64,
    'user_58': np.float64,
    'user_59': np.float64,

    'user_61': np.int64,
    'user_62': np.int64,
    'user_63': np.int64,
    'user_64': np.int64,
    'user_65': np.int64,
    'user_66': np.float64,
    'user_68': np.int64,
    'user_69': np.int64,

    'user_70': object,
    'user_71': bool,
    'user_72': np.int64,
    'user_73': bool,
    'user_74': bool,
    'user_75': np.int64,
    'user_76': bool,
    'user_77': bool,
    'user_78': bool,
    'user_79': bool,

    'user_80': bool,
    'user_81': bool,
    'user_82': np.int64,
    'user_83': np.int64,
    'user_84': bool,
    'user_85': np.int64,
    'user_86': np.int64,
    'user_87': object,
    'user_88': bool,
    'user_89': np.float64,

    'user_90': np.float64,
    'user_91': np.int64,
    'user_92': np.int64,
    'user_93': np.int64,
    'user_94': np.float64,
    'user_95': np.float64,
    'user_96': np.int64,
    'user_97': np.int64,
    'user_98': np.int64,
    'user_99': np.int64,
    
    'user_100': np.int64,
    'user_101': np.int64,
    'user_102': np.int64,
    'user_103': np.int64,
    'user_104': np.int64,
    'user_105': np.int64,
    'user_106': np.int64,
    'user_107': np.int64,
    'user_108': object,
    'user_109': bool,

    'user_110': bool,
    'user_111': np.int64,
    'user_112': np.int64,
    'user_113': np.int64,
    'user_114': np.int64,
    'user_115': np.int64,
    'user_116': bool,
    'user_117': np.int64,
    'user_118': np.int64,
    'user_119': np.int64,

    'user_120': np.int64,
    'user_121': np.int64,
    'user_122': np.int64,
    'user_123': bool,
    'user_124': np.int64,
    'user_125': np.int64,
    'user_126': np.int64,
    'user_127': np.int64,
    'user_128': np.int64,
    'user_129': np.int64,

    'user_130': np.int64,
    'user_131': np.int64,
    'user_132': np.int64,
    'user_133': np.int64,
    'user_134': np.int64,
    'user_135': np.int64,
    'user_136': np.int64,
    'user_137': np.int64,
    'user_138': np.int64,
    'user_139': np.int64,

    'user_140': np.int64,
    'user_141': bool,
    'user_142': np.float64,
    'user_143': np.int64,
    'user_144': np.int64,
    'user_146': bool,
    'user_147': bool,
    'user_148': np.int64,
    'user_149': np.int64,

    'user_150': bool,
    'user_151': object,
    'user_152': np.float64,
    'user_153': np.int64,
    'user_154': np.int64,
    'user_155': np.int64,
    'user_156': np.int64,
    'user_157': np.float64,
    'user_158': np.int64,
    'user_159': np.int64,

    'user_160': np.int64,
    'user_161': np.int64,
}

user_feature_names = list(user_feature_name_to_dtype.keys())



### organisation features

organisation_feature_name_to_dtype = {
    "date": object,
    "orgid": np.int64,
    "userid": np.int64,
    
    'org_2': np.float64,
    'org_3': np.float64,
    'org_4': np.int64,
    'org_5': np.int64,
    'org_8': np.float64,
    'org_9': object,
    'org_10': np.int64,

    'org_11': np.int64,
    'org_12': np.int64,
    'org_13': np.float64,
    'org_14': np.int64,
    'org_15': np.float64,
    'org_16': np.int64,
    'org_17': np.int64,
    'org_18': np.int64,
    'org_19': np.int64,

    'org_20': np.int64,
    'org_21': np.float64,
    'org_22': np.float64,
    'org_23': np.int64,
    'org_24': np.float64,
    'org_25': np.float64,
    'org_26': np.float64,
    'org_27': np.int64,
    'org_28': np.int64,
    'org_29': np.int64,

    'org_30': np.float64,
    'org_31': np.float64,
    'org_32': np.float64,
    'org_33': np.float64,
    'org_34': np.int64,
    'org_35': np.int64,
    'org_36': np.float64,
    'org_37': np.float64,
    'org_38': np.float64,
    'org_39': np.float64,

    'org_40': np.float64,
    'org_41': np.float64,
    'org_42': np.float64,
    'org_43': np.int64,
    'org_44': np.int64,
    'org_45': np.int64,
    'org_46': np.int64,
    'org_47': np.int64,
    'org_48': np.int64,
    'org_49': np.int64,
    
    'org_50': np.int64,
    'org_51': np.int64,
    'org_52': np.int64,
    'org_53': np.int64,
    'org_54': np.int64,
    'org_55': np.int64,
    'org_56': np.int64,
    'org_57': np.int64,
    'org_58': np.float64,
    'org_59': np.int64,

    'org_60': np.float64,
    'org_61': np.float64,
    'org_62': np.float64,
    'org_63': np.float64,
    'org_64': np.float64,
    'org_65': np.float64,
    'org_66': np.float64,
    'org_67': np.float64,
    'org_68': np.float64,
    'org_69': np.float64,

    'org_70': np.float64,
    'org_71': np.int64,
    'org_72': np.float64,
    'org_73': np.float64,
    'org_74': np.float64,
    'org_75': np.float64,
    'org_76': np.float64,
    'org_77': np.float64,
    'org_78': np.float64,
    'org_79': np.float64,

    'org_80': np.float64,
    'org_81': np.float64,
    'org_82': np.float64,
    'org_84': np.int64,
    'org_85': np.int64,
    'org_86': np.int64,
    'org_87': np.int64,
    'org_88': np.int64,
    'org_89': np.int64,

    'org_90': np.int64,
    'org_91': bool,
    'org_93': object,
    'org_94': np.float64,
    'org_95': np.int64,
    'org_98': np.int64,
    'org_99': np.float64,

    'org_100': np.int64,
    'org_101': object,
    'org_102': object,
    'org_103': np.int64,
    'org_104': np.int64,
    'org_105': np.float64,
    'org_106': np.float64,
    'org_107': np.int64,
    'org_108': np.int64,
    'org_109': np.int64,

    'org_110': np.int64,
    'org_111': np.int64,
    'org_112': np.float64,
    'org_113': np.int64,
    'org_114': np.int64,
    'org_115': np.int64,
    'org_117': np.int64,
    'org_118': bool,
    'org_119': bool,
}

organisation_feature_names = list(organisation_feature_name_to_dtype.keys())



### review features

review_feature_name_to_dtype = {
    "date": object,
    "orgid": np.int64,
    "userid": np.int64,
    
    'review_2': np.float64,
    'review_3': bool,
    'review_4': bool,
    'review_5': np.int64,
    'review_7': np.int64,
    'review_8': np.int64,
    'review_9': np.int64,
    
    'review_11': np.int64,
    'review_12': np.int64,
    'review_13': np.float64,
    'review_14': np.float64,
    'review_15': np.float64,
    'review_16': np.int64,
    'review_17': np.float64,
    'review_18': object,
    
    'review_20': np.int64,
    'review_21': np.int64,
    'review_22': np.int64,
    'review_23': np.int64,
    'review_24': np.int64,
    'review_26': object,
    'review_28': object,
    'review_29': np.int64,
    
    'review_30': np.float64,
    'review_31': bool,
    'review_32': np.float64,
    'review_36': bool,
    'review_37': bool,
    
}

review_feature_names = list(review_feature_name_to_dtype.keys())

target_name_to_dtype = {
    "date": object, 
    "orgid": np.int64, 
    "userid": np.int64, 
    "is_fraud": bool,
}

target_names = list(target_name_to_dtype.keys())

trust_indicator_name_to_dtype = {
    "date": object, 
    "orgid": np.int64, 
    "userid": np.int64, 
    "soft_trust": bool, 
    "strong_trust": bool, 
    "was_here": bool, 
    "has_paid_services": bool
}

trust_indicator_names = list(trust_indicator_name_to_dtype.keys())



FEATURE_TO_DTYPE = general_feature_name_to_dtype | user_feature_name_to_dtype | organisation_feature_name_to_dtype | review_feature_name_to_dtype | trust_indicator_name_to_dtype | target_name_to_dtype

# %%
dtype_mapper = {
    np.int64: "np.int32",
    np.float64: "np.float32",
    bool: "bool",
    object: "object",
}

# %%
STRING = []

for feat, dtype in FEATURE_TO_DTYPE.items():
    STRING.append(f"'{feat}': {dtype_mapper.get(dtype, dtype)}")
    
STRING = ',\n'.join(STRING)

STRING = "{" + STRING + ",\n}"
print(STRING)
# Out:
# {'date': object,
# 'orgid': np.int32,
# 'userid': np.int32,
# 'has_reaction': bool,
# 'has_review': bool,
# 'rating': np.int32,
# 'reaction': object,
# 'time': np.int32,
# 'user_1': np.int32,
# 'user_4': np.int32,
# 'user_5': object,
# 'user_6': object,
# 'user_8': object,
# 'user_9': np.int32,
# 'user_10': np.int32,
# 'user_12': np.int32,
# 'user_13': object,
# 'user_15': np.int32,
# 'user_16': bool,
# 'user_17': np.int32,
# 'user_18': np.int32,
# 'user_19': np.int32,
# 'user_21': object,
# 'user_22': object,
# 'user_23': object,
# 'user_24': object,
# 'user_25': object,
# 'user_26': object,
# 'user_27': object,
# 'user_28': object,
# 'user_29': object,
# 'user_30': object,
# 'user_31': object,
# 'user_32': object,
# 'user_33': object,
# 'user_34': object,
# 'user_35': object,
# 'user_36': object,
# 'user_37': object,
# 'user_38': object,
# 'user_39': object,
# 'user_40': object,
# 'user_41': object,
# 'user_42': object,
# 'user_43': object,
# 'user_44': object,
# ...

# %%
FEATURE_TO_DTYPE = {'date': object,
'orgid': np.int32,
'userid': np.int32,
'has_reaction': bool,
'has_review': bool,
'rating': np.int32,
'reaction': object,
'time': np.int32,
'user_1': np.int32,
'user_4': np.int32,
'user_5': object,
'user_6': object,
'user_8': object,
'user_9': np.int32,
'user_10': np.int32,
'user_12': np.int32,
'user_13': object,
'user_15': np.int32,
'user_16': bool,
'user_17': np.int32,
'user_18': np.int32,
'user_19': np.int32,
'user_21': object,
'user_22': object,
'user_23': object,
'user_24': object,
'user_25': object,
'user_26': object,
'user_27': object,
'user_28': object,
'user_29': object,
'user_30': object,
'user_31': object,
'user_32': object,
'user_33': object,
'user_34': object,
'user_35': object,
'user_36': object,
'user_37': object,
'user_38': object,
'user_39': object,
'user_40': object,
'user_41': object,
'user_42': object,
'user_43': object,
'user_44': object,
'user_45': object,
'user_46': object,
'user_47': object,
'user_48': object,
'user_49': object,
'user_50': object,
'user_51': object,
'user_52': object,
'user_53': object,
'user_54': object,
'user_55': object,
'user_56': object,
'user_57': np.float32,
'user_58': np.float32,
'user_59': np.float32,
'user_61': np.int32,
'user_62': np.int32,
'user_63': np.int32,
'user_64': np.int32,
'user_65': np.int32,
'user_66': np.float32,
'user_68': np.int32,
'user_69': np.int32,
'user_70': object,
'user_71': bool,
'user_72': np.int32,
'user_73': bool,
'user_74': bool,
'user_75': np.int32,
'user_76': bool,
'user_77': bool,
'user_78': bool,
'user_79': bool,
'user_80': bool,
'user_81': bool,
'user_82': np.int32,
'user_83': np.int32,
'user_84': bool,
'user_85': np.int32,
'user_86': np.int32,
'user_87': object,
'user_88': bool,
'user_89': np.float32,
'user_90': np.float32,
'user_91': np.int32,
'user_92': np.int32,
'user_93': np.int32,
'user_94': np.float32,
'user_95': np.float32,
'user_96': np.int32,
'user_97': np.int32,
'user_98': np.int32,
'user_99': np.int32,
'user_100': np.int32,
'user_101': np.int32,
'user_102': np.int32,
'user_103': np.int32,
'user_104': np.int32,
'user_105': np.int32,
'user_106': np.int32,
'user_107': np.int32,
'user_108': object,
'user_109': bool,
'user_110': bool,
'user_111': np.int32,
'user_112': np.int32,
'user_113': np.int32,
'user_114': np.int32,
'user_115': np.int32,
'user_116': bool,
'user_117': np.int32,
'user_118': np.int32,
'user_119': np.int32,
'user_120': np.int32,
'user_121': np.int32,
'user_122': np.int32,
'user_123': bool,
'user_124': np.int32,
'user_125': np.int32,
'user_126': np.int32,
'user_127': np.int32,
'user_128': np.int32,
'user_129': np.int32,
'user_130': np.int32,
'user_131': np.int32,
'user_132': np.int32,
'user_133': np.int32,
'user_134': np.int32,
'user_135': np.int32,
'user_136': np.int32,
'user_137': np.int32,
'user_138': np.int32,
'user_139': np.int32,
'user_140': np.int32,
'user_141': bool,
'user_142': np.float32,
'user_143': np.int32,
'user_144': np.int32,
'user_146': bool,
'user_147': bool,
'user_148': np.int32,
'user_149': np.int32,
'user_150': bool,
'user_151': object,
'user_152': np.float32,
'user_153': np.int32,
'user_154': np.int32,
'user_155': np.int32,
'user_156': np.int32,
'user_157': np.float32,
'user_158': np.int32,
'user_159': np.int32,
'user_160': np.int32,
'user_161': np.int32,
'org_2': np.float32,
'org_3': np.float32,
'org_4': np.int32,
'org_5': np.int32,
'org_8': np.float32,
'org_9': object,
'org_10': np.int32,
'org_11': np.int32,
'org_12': np.int32,
'org_13': np.float32,
'org_14': np.int32,
'org_15': np.float32,
'org_16': np.int32,
'org_17': np.int32,
'org_18': np.int32,
'org_19': np.int32,
'org_20': np.int32,
'org_21': np.float32,
'org_22': np.float32,
'org_23': np.int32,
'org_24': np.float32,
'org_25': np.float32,
'org_26': np.float32,
'org_27': np.int32,
'org_28': np.int32,
'org_29': np.int32,
'org_30': np.float32,
'org_31': np.float32,
'org_32': np.float32,
'org_33': np.float32,
'org_34': np.int32,
'org_35': np.int32,
'org_36': np.float32,
'org_37': np.float32,
'org_38': np.float32,
'org_39': np.float32,
'org_40': np.float32,
'org_41': np.float32,
'org_42': np.float32,
'org_43': np.int32,
'org_44': np.int32,
'org_45': np.int32,
'org_46': np.int32,
'org_47': np.int32,
'org_48': np.int32,
'org_49': np.int32,
'org_50': np.int32,
'org_51': np.int32,
'org_52': np.int32,
'org_53': np.int32,
'org_54': np.int32,
'org_55': np.int32,
'org_56': np.int32,
'org_57': np.int32,
'org_58': np.float32,
'org_59': np.int32,
'org_60': np.float32,
'org_61': np.float32,
'org_62': np.float32,
'org_63': np.float32,
'org_64': np.float32,
'org_65': np.float32,
'org_66': np.float32,
'org_67': np.float32,
'org_68': np.float32,
'org_69': np.float32,
'org_70': np.float32,
'org_71': np.int32,
'org_72': np.float32,
'org_73': np.float32,
'org_74': np.float32,
'org_75': np.float32,
'org_76': np.float32,
'org_77': np.float32,
'org_78': np.float32,
'org_79': np.float32,
'org_80': np.float32,
'org_81': np.float32,
'org_82': np.float32,
'org_84': np.int32,
'org_85': np.int32,
'org_86': np.int32,
'org_87': np.int32,
'org_88': np.int32,
'org_89': np.int32,
'org_90': np.int32,
'org_91': bool,
'org_93': object,
'org_94': np.float32,
'org_95': np.int32,
'org_98': np.int32,
'org_99': np.float32,
'org_100': np.int32,
'org_101': object,
'org_102': object,
'org_103': np.int32,
'org_104': np.int32,
'org_105': np.float32,
'org_106': np.float32,
'org_107': np.int32,
'org_108': np.int32,
'org_109': np.int32,
'org_110': np.int32,
'org_111': np.int32,
'org_112': np.float32,
'org_113': np.int32,
'org_114': np.int32,
'org_115': np.int32,
'org_117': np.int32,
'org_118': bool,
'org_119': bool,
'review_2': np.float32,
'review_3': bool,
'review_4': bool,
'review_5': np.int32,
'review_7': np.int32,
'review_8': np.int32,
'review_9': np.int32,
'review_11': np.int32,
'review_12': np.int32,
'review_13': np.float32,
'review_14': np.float32,
'review_15': np.float32,
'review_16': np.int32,
'review_17': np.float32,
'review_18': object,
'review_20': np.int32,
'review_21': np.int32,
'review_22': np.int32,
'review_23': np.int32,
'review_24': np.int32,
'review_26': object,
'review_28': object,
'review_29': np.int32,
'review_30': np.float32,
'review_31': bool,
'review_32': np.float32,
'review_36': bool,
'review_37': bool,
'soft_trust': bool,
'strong_trust': bool,
'was_here': bool,
'has_paid_services': bool,
'is_fraud': bool,
'hash': object,
}

# %%
feature_dtype_to_value = {
        object: "",
        bool: False,
        np.int32: 0,
        np.float32: 0.0,
    }

columns_types = {}

for col in train_df.columns:
    
    col_desired_dtype = FEATURE_TO_DTYPE[col]
    
    nan_val_replacer = feature_dtype_to_value[col_desired_dtype]
    
    
    train_df[col] = np.nan_to_num(train_df[col].values, nan_val_replacer)
    
    columns_types[col] = col_desired_dtype
    



train_df = train_df.astype(columns_types)

float_cols = train_df.select_dtypes(include=["floating"]).columns
str_cols = train_df.select_dtypes(include=['object']).columns
int_cols = train_df.select_dtypes(include=["integer"]).columns
bool_cols = train_df.select_dtypes(include=["bool"]).columns

train_df.loc[:, float_cols] = train_df.loc[:, float_cols].fillna(0.0)
train_df.loc[:, str_cols] = train_df.loc[:, str_cols].fillna("")
train_df.loc[:, int_cols] = train_df.loc[:, int_cols].fillna(0)
train_df.loc[:, bool_cols] = train_df.loc[:, bool_cols].fillna(False)

# %%
train_df["user_86"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: user_86, Length: 1000, dtype: int32

# %%
import yt.wrapper as yt
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import torch
import copy

# %%
dtypes = list(set(train_df.dtypes))
dtypes
# Out:
# [dtype('int64'), dtype('float64'), dtype('O'), dtype('bool')]

# %%
float_cols = train_df.select_dtypes(include=["floating"]).columns
str_cols = train_df.select_dtypes(include=['object']).columns
int_cols = train_df.select_dtypes(include=["integer"]).columns
bool_cols = train_df.select_dtypes(include=["bool"]).columns

# %%
isna = train_df.isna().sum()
for col in isna.index:
    if isna[col] >0:
        print(col, isna[col], train_df.dtypes[col])
# Out:
# org_101 42 object
# org_102 40 object
# org_93 40 object
# review_18 260 object
# user_108 86 object
# user_21 259 object
# user_22 259 object
# user_23 259 object
# user_24 259 object
# user_25 259 object
# user_26 259 object
# user_27 259 object
# user_28 259 object
# user_29 259 object
# user_30 259 object
# user_31 259 object
# user_32 259 object
# user_33 495 object
# user_34 259 object
# user_35 259 object
# user_36 259 object
# user_37 259 object
# user_38 259 object
# user_39 259 object
# user_40 259 object
# user_41 259 object
# user_42 259 object
# user_43 259 object
# user_44 259 object
# user_45 259 object
# user_46 259 object
# user_47 259 object
# user_48 259 object
# user_49 259 object
# user_5 86 object
# user_50 259 object
# user_51 259 object
# user_52 259 object
# user_53 259 object
# user_54 259 object
# user_55 259 object
# user_56 259 object
# user_6 259 object
# user_8 259 object
# user_87 105 object

# %%
subset = {key: val for key, val in FEATURE_TO_DTYPE.items() if key in train_df.columns}

# %%
train_df.astype(subset)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train_df.astype(subset)
#
# File ~/miniconda3/envs/fraud_detect/lib/python3.9/site-packages/pandas/core/generic.py:6305, in NDFrame.astype(self, dtype, copy, errors)
#    6303 else:
#    6304     try:
# -> 6305         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6306     except ValueError as ex:
#    6307         ex.args = (
#    6308             f"{ex}: Error while type casting for column '{col_name}'",
#    6309         )
#
# File ~/miniconda3/envs/fraud_detect/lib/python3.9/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# ...
